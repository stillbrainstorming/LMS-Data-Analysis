# %% [markdown]
# # LMS Reviews Analysis
#
# This notebook is the reproducible analysis/reference workflow for the project. Core transformations live in the `src` package.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd()
if not (ROOT / 'src').exists():
    ROOT = ROOT.parent
sys.path.insert(0, str(ROOT))

from src.data.reviews import load_reviews
from src.analysis.pain_points import add_pain_points
from src.analysis.sentiment import add_sentiment
from src.models.segmentation import add_user_segments
from src.analysis.aggregates import (
    summary_metrics,
    rating_distribution,
    sentiment_distribution,
    segment_distribution,
    pain_point_counts,
    pain_points_by_rating,
    sentiment_vs_rating,
    pain_point_cooccurrence,
    one_star_pain_share,
)

# %%
data_path = ROOT / 'data' / 'lms_reviews_segmented.csv'
df = load_reviews(data_path)
df = add_sentiment(df)
df = add_pain_points(df)
df = add_user_segments(df)
print(df.shape)

# %% [markdown]
# ## Summary

# %%
print(summary_metrics(df))
print(rating_distribution(df))
print(sentiment_distribution(df))
print(segment_distribution(df))

# %% [markdown]
# ## Pain points and relationships

# %%
print(pain_point_counts(df))
print(pain_points_by_rating(df))
print(sentiment_vs_rating(df))
print(pain_point_cooccurrence(df))
print(one_star_pain_share(df))
